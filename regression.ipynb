# %%
from sklearn.datasets import load_iris
from sklearn import datasets
import matplotlib.pyplot as plt
import numpy as np
iris = datasets.load_iris()

# %%
# %matplotlib inline

# %%
x_index=3
colors=['blue','red','green']
for label,color in zip(range(len(iris.target_names)),colors):
                       plt.hist(iris.data[iris.target==label,x_index],color=color,
                               label=iris.target_names[label])
plt.show()

# %%
import pandas as pd
df=pd.DataFrame(iris.data,columns=iris.feature_names)
pd.plotting.scatter_matrix(df,c=iris.target)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022BE3C9DB70>,
# ...
#       dtype=object)

# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
boston=load_boston()

# %%
# %matplotlib inline

# %%
X=pd.DataFrame(boston.data,columns=boston.feature_names)
y=pd.Series(boston.target)
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
plt.scatter(X.RM,y,marker='.')
plt.xlabel('numbers of rooms')
plt.ylabel('price')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2)

print('X_train.shape =', X_train.shape)
print('X_test.shape =', X_test.shape)
print('y_train.shape =', y_train.shape)
print('y_test.shape =', y_test.shape)



from sklearn import preprocessing

X_train = preprocessing.scale(X_train)
X_test = preprocessing.scale(X_test)
# Out:
# X_train.shape = (404, 13)
# X_test.shape = (102, 13)
# y_train.shape = (404,)
# y_test.shape = (102,)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
data=np.loadtxt('/Users/user/Desktop/Machine Learning/exercise_ml/machine-learning-ex1/ex1/ex1data1.txt',delimiter=',')

# %%
x=data[:,0]
y=data[:,1]
# Out:
# [ 6.1101  5.5277  8.5186  7.0032  5.8598  8.3829  7.4764  8.5781  6.4862
#   5.0546  5.7107 14.164   5.734   8.4084  5.6407  5.3794  6.3654  5.1301
#   6.4296  7.0708  6.1891 20.27    5.4901  6.3261  5.5649 18.945  12.828
#  10.957  13.176  22.203   5.2524  6.5894  9.2482  5.8918  8.2111  7.9334
#   8.0959  5.6063 12.836   6.3534  5.4069  6.8825 11.708   5.7737  7.8247
#   7.0931  5.0702  5.8014 11.7     5.5416  7.5402  5.3077  7.4239  7.6031
#   6.3328  6.3589  6.2742  5.6397  9.3102  9.4536  8.8254  5.1793 21.279
#  14.908  18.959   7.2182  8.2951 10.236   5.4994 20.341  10.136   7.3345
#   6.0062  7.2259  5.0269  6.5479  7.5386  5.0365 10.274   5.1077  5.7292
#   5.1884  6.3557  9.7687  6.5159  8.5172  9.1802  6.002   5.5204  5.0594
#   5.7077  7.6366  5.8707  5.3054  8.2934 13.394   5.4369]

# %%
x=np.array(x).reshape(-1,1)
y=np.array(y).reshape(-1,1)

# %%
plt.scatter(x,y)
plt.ylabel('Profit in $10,000')
plt.xlabel('Population of City in 10,000s')
# Out:
# Text(0.5, 0, 'Population of City in 10,000s')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)

# %%
model=LinearRegression().fit(x_train,y_train)

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [[1.25892091]]
# [-4.4420632]

# %%
model.score(x_test,y_test)
# Out:
# 0.6988962911386083

# %%
y_pred=model.predict(x_test)

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_pred)
plt.legend(['Training data', 'Linear regression']);

# %%
res=20.341*model.coef_[0]+model.intercept_

# %%
print(res)
# Out:
# [21.16564693]

# %%
x_test
# Out:
# array([[ 5.7107],
#        [ 9.4536],
#        [ 5.8598],
#        [ 6.5894],
#        [ 7.0032],
#        [ 8.4084],
#        [ 8.0959],
#        [ 5.8918],
#        [ 6.8825],
#        [21.279 ],
#        [ 6.3589],
#        [20.341 ],
#        [18.959 ],
#        [ 5.5649],
#        [ 7.9334],
#        [ 7.0708],
#        [ 9.3102],
#        [ 6.3261],
#        [ 5.2524],
#        [ 8.5186]])
